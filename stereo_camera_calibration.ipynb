# %%
import numpy as np
import cv2
import glob
import pickle
# import argparse

# %%
NUM_IMAGES = 1000

# %%
class StereoCalibration(object):
    def __init__(self, filepath, show_corner=False):
        # termination criteria
        self.criteria = (cv2.TERM_CRITERIA_EPS +
                         cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
        self.criteria_cal = (cv2.TERM_CRITERIA_EPS +
                             cv2.TERM_CRITERIA_MAX_ITER, 100, 1e-5)
        self.M1 = None
        self.M2 = None
        self.show_corner = show_corner

        # prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
        self.objp = np.zeros((9*6, 3), np.float32)
        self.objp[:, :2] = np.mgrid[0:9, 0:6].T.reshape(-1, 2)

        # Arrays to store object points and image points from all the images.
        self.objpoints = []  # 3d point in real world space
        self.imgpoints_l = []  # 2d points in image plane.
        self.imgpoints_r = []  # 2d points in image plane.

        self.cal_path = filepath
        self.read_images(self.cal_path)

    def read_images(self, cal_path):
        images_right = glob.glob(cal_path + 'right/' + '*r.png')
        images_left = glob.glob(cal_path + 'left/' + '*l.png')
        print(f"Found {len(images_left)} left camera images")
        print(f"Found {len(images_right)} right camera images")
        images_left.sort()
        images_right.sort()

        for i, fname in enumerate(images_right):
            print("processing pair {}...".format(i))
            img_l = cv2.imread(images_left[i])
            img_r = cv2.imread(images_right[i])

            gray_l = cv2.cvtColor(img_l, cv2.COLOR_BGR2GRAY)
            gray_r = cv2.cvtColor(img_r, cv2.COLOR_BGR2GRAY)

            # Find the chess board corners
            ret_l, corners_l = cv2.findChessboardCorners(gray_l, (9, 6), None)
            ret_r, corners_r = cv2.findChessboardCorners(gray_r, (9, 6), None)

            if ret_l and ret_r:
                # If found, add object points, image points (after refining them)
                self.objpoints.append(self.objp)
            
                rt = cv2.cornerSubPix(gray_l, corners_l, (11, 11),
                                      (-1, -1), self.criteria)
                self.imgpoints_l.append(corners_l)

                # Draw and display the corners
                ret_l = cv2.drawChessboardCorners(img_l, (9, 6),
                                                  corners_l, ret_l)
                if self.show_corner:
                    cv2.imshow(images_left[i], img_l)
                    cv2.waitKey(500)

                rt = cv2.cornerSubPix(gray_r, corners_r, (11, 11),
                                      (-1, -1), self.criteria)
                self.imgpoints_r.append(corners_r)

                # Draw and display the corners
                ret_r = cv2.drawChessboardCorners(img_r, (9, 6),
                                                  corners_r, ret_r)
                if self.show_corner:
                    cv2.imshow(images_right[i], img_r)
                    cv2.waitKey(500)
            img_shape = gray_l.shape[::-1]

        print(len(self.objpoints))
        print(len(self.imgpoints_l))
        print(len(self.imgpoints_r))
        
        rt, self.M1, self.d1, self.r1, self.t1 = cv2.calibrateCamera(
            self.objpoints[:NUM_IMAGES], self.imgpoints_l[:NUM_IMAGES], img_shape, None, None)
        rt, self.M2, self.d2, self.r2, self.t2 = cv2.calibrateCamera(
            self.objpoints[:NUM_IMAGES], self.imgpoints_r[:NUM_IMAGES], img_shape, None, None)

        print("finish calibrating")
        self.camera_model = self.stereo_calibrate(img_shape)

    def stereo_calibrate(self, dims):
        flags = 0
        flags |= cv2.CALIB_FIX_INTRINSIC
        # flags |= cv2.CALIB_FIX_PRINCIPAL_POINT
        flags |= cv2.CALIB_USE_INTRINSIC_GUESS
        # flags |= cv2.CALIB_USE_EXTRINSIC_GUESS
        flags |= cv2.CALIB_FIX_FOCAL_LENGTH
        # flags |= cv2.CALIB_FIX_ASPECT_RATIO
        flags |= cv2.CALIB_ZERO_TANGENT_DIST
        # flags |= cv2.CALIB_RATIONAL_MODEL
        # flags |= cv2.CALIB_SAME_FOCAL_LENGTH
        # flags |= cv2.CALIB_FIX_K3
        # flags |= cv2.CALIB_FIX_K4
        # flags |= cv2.CALIB_FIX_K5

        stereocalib_criteria = (cv2.TERM_CRITERIA_MAX_ITER +
                                cv2.TERM_CRITERIA_EPS, 100, 1e-5)
        
        print("start modelling")
        ret, M1, d1, M2, d2, R, T, E, F = cv2.stereoCalibrate(
            self.objpoints[:NUM_IMAGES], self.imgpoints_l[:NUM_IMAGES],
            self.imgpoints_r[:NUM_IMAGES], self.M1, self.d1, self.M2,
            self.d2, dims,
            criteria=stereocalib_criteria, flags=flags)

        print('Intrinsic_mtx_1', M1)
        print('dist_1', d1)
        print('Intrinsic_mtx_2', M2)
        print('dist_2', d2)
        print('R', R)
        print('T', T)
        print('E', E)
        print('F', F)

        # for i in range(len(self.r1)):
        #     print("--- pose[", i+1, "] ---")
        #     self.ext1, _ = cv2.Rodrigues(self.r1[i])
        #     self.ext2, _ = cv2.Rodrigues(self.r2[i])
        #     print('Ext1', self.ext1)
        #     print('Ext2', self.ext2)

        print('')

        camera_model = dict([('M1', M1), ('M2', M2), ('dist1', d1),
                            ('dist2', d2), ('rvecs1', self.r1),
                            ('rvecs2', self.r2), ('R', R), ('T', T),
                            ('E', E), ('F', F)])

        cv2.destroyAllWindows()
        print("finish modeling")
        
#         with open("camera_model.json", "w") as outfile:
#             json.dump(dictionary, outfile, indent=4)
        
        return camera_model

# %%
if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('filepath', help='String Filepath')
#     args = parser.parse_args()
    cal_data = StereoCalibration("./stereo/calib/")
    with open("camera_model.pickle", "wb") as outfile:
        pickle.dump(cal_data, outfile)
    StereoCalibration("./stereo/calib/", False)
# Out:
# Found 12968 left camera images
# Found 12968 right camera images
# processing pair 0...
# processing pair 1...
# processing pair 2...
# processing pair 3...
# processing pair 4...
# processing pair 5...
# processing pair 6...
# processing pair 7...
# processing pair 8...
# processing pair 9...
# processing pair 10...
# processing pair 11...
# processing pair 12...
# processing pair 13...
# processing pair 14...
# processing pair 15...
# processing pair 16...
# processing pair 17...
# processing pair 18...
# processing pair 19...
# processing pair 20...
# processing pair 21...
# processing pair 22...
# processing pair 23...
# processing pair 24...
# processing pair 25...
# processing pair 26...
# processing pair 27...
# processing pair 28...
# processing pair 29...
# processing pair 30...
# processing pair 31...
# processing pair 32...
# processing pair 33...
# processing pair 34...
# processing pair 35...
# processing pair 36...
# processing pair 37...
# processing pair 38...
# processing pair 39...
# processing pair 40...
# processing pair 41...
# processing pair 42...
# processing pair 43...
# processing pair 44...
# processing pair 45...
# processing pair 46...
# processing pair 47...
# processing pair 48...
# processing pair 49...
# processing pair 50...
# processing pair 51...
# processing pair 52...
# processing pair 53...
# processing pair 54...
# processing pair 55...
# processing pair 56...
# processing pair 57...
# processing pair 58...
# processing pair 59...
# processing pair 60...
# processing pair 61...
# processing pair 62...
# processing pair 63...
# processing pair 64...
# processing pair 65...
# processing pair 66...
# processing pair 67...
# processing pair 68...
# processing pair 69...
# processing pair 70...
# processing pair 71...
# processing pair 72...
# processing pair 73...
# processing pair 74...
# processing pair 75...
# processing pair 76...
# processing pair 77...
# processing pair 78...
# processing pair 79...
# processing pair 80...
# processing pair 81...
# processing pair 82...
# processing pair 83...
# processing pair 84...
# processing pair 85...
# processing pair 86...
# processing pair 87...
# processing pair 88...
# processing pair 89...
# processing pair 90...
# processing pair 91...
# processing pair 92...
# processing pair 93...
# processing pair 94...
# processing pair 95...
# processing pair 96...
# processing pair 97...
# processing pair 98...
# processing pair 99...
# processing pair 100...
# processing pair 101...
# processing pair 102...
# processing pair 103...
# processing pair 104...
# processing pair 105...
# processing pair 106...
# processing pair 107...
# processing pair 108...
# processing pair 109...
# processing pair 110...
# processing pair 111...
# processing pair 112...
# processing pair 113...
# processing pair 114...
# processing pair 115...
# processing pair 116...
# processing pair 117...
# processing pair 118...
# processing pair 119...
# processing pair 120...
# processing pair 121...
# processing pair 122...
# processing pair 123...
# processing pair 124...
# processing pair 125...
# processing pair 126...
# processing pair 127...
# processing pair 128...
# processing pair 129...
# processing pair 130...
# processing pair 131...
# processing pair 132...
# processing pair 133...
# processing pair 134...
# processing pair 135...
# processing pair 136...
# processing pair 137...
# processing pair 138...
# processing pair 139...
# processing pair 140...
# processing pair 141...
# processing pair 142...
# processing pair 143...
# processing pair 144...
# processing pair 145...
# processing pair 146...
# processing pair 147...
# processing pair 148...
# processing pair 149...
# processing pair 150...
# processing pair 151...
# processing pair 152...
# processing pair 153...
# processing pair 154...
# processing pair 155...
# processing pair 156...
# processing pair 157...
# processing pair 158...
# processing pair 159...
# processing pair 160...
# processing pair 161...
# processing pair 162...
# processing pair 163...
# processing pair 164...
# processing pair 165...
# processing pair 166...
# processing pair 167...
# processing pair 168...
# processing pair 169...
# processing pair 170...
# processing pair 171...
# processing pair 172...
# processing pair 173...
# processing pair 174...
# processing pair 175...
# processing pair 176...
# processing pair 177...
# processing pair 178...
# processing pair 179...
# processing pair 180...
# processing pair 181...
# processing pair 182...
# processing pair 183...
# processing pair 184...
# processing pair 185...
# processing pair 186...
# processing pair 187...
# processing pair 188...
# processing pair 189...
# processing pair 190...
# processing pair 191...
# processing pair 192...
# processing pair 193...
# processing pair 194...
# processing pair 195...
# processing pair 196...
# processing pair 197...
# processing pair 198...
# processing pair 199...
# processing pair 200...
# processing pair 201...
# processing pair 202...
# processing pair 203...
# processing pair 204...
# processing pair 205...
# processing pair 206...
# processing pair 207...
# processing pair 208...
# processing pair 209...
# processing pair 210...
# processing pair 211...
# processing pair 212...
# processing pair 213...
# processing pair 214...
# processing pair 215...
# processing pair 216...
# processing pair 217...
# processing pair 218...
# processing pair 219...
# processing pair 220...
# processing pair 221...
# processing pair 222...
# processing pair 223...
# processing pair 224...
# processing pair 225...
# processing pair 226...
# processing pair 227...
# processing pair 228...
# processing pair 229...
# processing pair 230...
# processing pair 231...
# processing pair 232...
# processing pair 233...
# processing pair 234...
# processing pair 235...
# processing pair 236...
# processing pair 237...
# processing pair 238...
# processing pair 239...
# processing pair 240...
# processing pair 241...
# processing pair 242...
# processing pair 243...
# processing pair 244...
# processing pair 245...
# processing pair 246...
# processing pair 247...
# processing pair 248...
# processing pair 249...
# processing pair 250...
# processing pair 251...
# processing pair 252...
# processing pair 253...
# processing pair 254...
# processing pair 255...
# processing pair 256...
# processing pair 257...
# processing pair 258...
# processing pair 259...
# processing pair 260...
# processing pair 261...
# processing pair 262...
# processing pair 263...
# processing pair 264...
# processing pair 265...
# processing pair 266...
# processing pair 267...
# processing pair 268...
# processing pair 269...
# processing pair 270...
# processing pair 271...
# processing pair 272...
# processing pair 273...
# processing pair 274...
# processing pair 275...
# processing pair 276...
# processing pair 277...
# processing pair 278...
# processing pair 279...
# processing pair 280...
# processing pair 281...
# processing pair 282...
# processing pair 283...
# processing pair 284...
# processing pair 285...
# processing pair 286...
# processing pair 287...
# processing pair 288...
# processing pair 289...
# processing pair 290...
# processing pair 291...
# processing pair 292...
# processing pair 293...
# processing pair 294...
# processing pair 295...
# processing pair 296...
# processing pair 297...
# processing pair 298...
# processing pair 299...
# processing pair 300...
# processing pair 301...
# processing pair 302...
# processing pair 303...
# processing pair 304...
# processing pair 305...
# processing pair 306...
# processing pair 307...
# processing pair 308...
# processing pair 309...
# processing pair 310...
# processing pair 311...
# processing pair 312...
# processing pair 313...
# processing pair 314...
# processing pair 315...
# processing pair 316...
# processing pair 317...
# processing pair 318...
# processing pair 319...
# processing pair 320...
# processing pair 321...
# processing pair 322...
# processing pair 323...
# processing pair 324...
# processing pair 325...
# processing pair 326...
# processing pair 327...
# processing pair 328...
# processing pair 329...
# processing pair 330...
# processing pair 331...
# processing pair 332...
# processing pair 333...
# processing pair 334...
# processing pair 335...
# processing pair 336...
# processing pair 337...
# processing pair 338...
# processing pair 339...
# processing pair 340...
# processing pair 341...
# processing pair 342...
# processing pair 343...
# processing pair 344...
# processing pair 345...
# processing pair 346...
# processing pair 347...
# processing pair 348...
# processing pair 349...
# processing pair 350...
# processing pair 351...
# processing pair 352...
# processing pair 353...
# processing pair 354...
# processing pair 355...
# processing pair 356...
# processing pair 357...
# processing pair 358...
# processing pair 359...
# processing pair 360...
# processing pair 361...
# processing pair 362...
# processing pair 363...
# processing pair 364...
# processing pair 365...
# processing pair 366...
# processing pair 367...
# processing pair 368...
# processing pair 369...
# processing pair 370...
# processing pair 371...
# processing pair 372...
# processing pair 373...
# processing pair 374...
# processing pair 375...
# processing pair 376...
# processing pair 377...
# processing pair 378...
# processing pair 379...
# processing pair 380...
# processing pair 381...
# processing pair 382...
# processing pair 383...
# processing pair 384...
# processing pair 385...
# processing pair 386...
# processing pair 387...
# processing pair 388...
# processing pair 389...
# processing pair 390...
# processing pair 391...
# processing pair 392...
# processing pair 393...
# processing pair 394...
# processing pair 395...
# processing pair 396...
# processing pair 397...
# processing pair 398...
# processing pair 399...
# processing pair 400...
# processing pair 401...
# processing pair 402...
# processing pair 403...
# processing pair 404...
# processing pair 405...
# processing pair 406...
# processing pair 407...
# processing pair 408...
# processing pair 409...
# processing pair 410...
# processing pair 411...
# processing pair 412...
# processing pair 413...
# processing pair 414...
# processing pair 415...
# processing pair 416...
# processing pair 417...
# processing pair 418...
# processing pair 419...
# processing pair 420...
# processing pair 421...
# processing pair 422...
# processing pair 423...
# processing pair 424...
# processing pair 425...
# processing pair 426...
# processing pair 427...
# processing pair 428...
# processing pair 429...
# processing pair 430...
# processing pair 431...
# processing pair 432...
# processing pair 433...
# processing pair 434...
# processing pair 435...
# processing pair 436...
# processing pair 437...
# processing pair 438...
# processing pair 439...
# processing pair 440...
# processing pair 441...
# processing pair 442...
# processing pair 443...
# processing pair 444...
# processing pair 445...
# processing pair 446...
# processing pair 447...
# processing pair 448...
# processing pair 449...
# processing pair 450...
# processing pair 451...
# processing pair 452...
# processing pair 453...
# processing pair 454...
# processing pair 455...
# processing pair 456...
# processing pair 457...
# processing pair 458...
# processing pair 459...
# processing pair 460...
# processing pair 461...
# processing pair 462...
# processing pair 463...
# processing pair 464...
# processing pair 465...
# processing pair 466...
# processing pair 467...
# processing pair 468...
# processing pair 469...
# processing pair 470...
# processing pair 471...
# processing pair 472...
# processing pair 473...
# processing pair 474...
# processing pair 475...
# processing pair 476...
# processing pair 477...
# processing pair 478...
# processing pair 479...
# processing pair 480...
# processing pair 481...
# processing pair 482...
# processing pair 483...
# processing pair 484...
# processing pair 485...
# processing pair 486...
# processing pair 487...
# processing pair 488...
# processing pair 489...
# processing pair 490...
# processing pair 491...
# processing pair 492...
# processing pair 493...
# processing pair 494...
# processing pair 495...
# processing pair 496...
# processing pair 497...
# processing pair 498...
# processing pair 499...
# processing pair 500...
# processing pair 501...
# processing pair 502...
# processing pair 503...
# processing pair 504...
# processing pair 505...
# processing pair 506...
# processing pair 507...
# processing pair 508...
# processing pair 509...
# processing pair 510...
# processing pair 511...
# processing pair 512...
# processing pair 513...
# processing pair 514...
# processing pair 515...
# processing pair 516...
# processing pair 517...
# processing pair 518...
# processing pair 519...
# processing pair 520...
# processing pair 521...
# processing pair 522...
# processing pair 523...
# processing pair 524...
# processing pair 525...
# processing pair 526...
# processing pair 527...
# processing pair 528...
# processing pair 529...
# processing pair 530...
# processing pair 531...
# processing pair 532...
# processing pair 533...
# processing pair 534...
# processing pair 535...
# processing pair 536...
# processing pair 537...
# processing pair 538...
# processing pair 539...
# processing pair 540...
# processing pair 541...
# processing pair 542...
# processing pair 543...
# processing pair 544...
# processing pair 545...
# processing pair 546...
# processing pair 547...
# processing pair 548...
# processing pair 549...
# processing pair 550...
# processing pair 551...
# processing pair 552...
# processing pair 553...
# processing pair 554...
# processing pair 555...
# processing pair 556...
# processing pair 557...
# processing pair 558...
# processing pair 559...
# processing pair 560...
# processing pair 561...
# processing pair 562...
# processing pair 563...
# processing pair 564...
# processing pair 565...
# processing pair 566...
# processing pair 567...
# processing pair 568...
# processing pair 569...
# processing pair 570...
# processing pair 571...
# processing pair 572...
# processing pair 573...
# processing pair 574...
# processing pair 575...
# processing pair 576...
# processing pair 577...
# processing pair 578...
# processing pair 579...
# processing pair 580...
# processing pair 581...
# processing pair 582...
# processing pair 583...
# processing pair 584...
# processing pair 585...
# processing pair 586...
# processing pair 587...
# processing pair 588...
# processing pair 589...
# processing pair 590...
# processing pair 591...
# processing pair 592...
# processing pair 593...
# processing pair 594...
# processing pair 595...
# processing pair 596...
# processing pair 597...
# processing pair 598...
# processing pair 599...
# processing pair 600...
# processing pair 601...
# processing pair 602...
# processing pair 603...
# processing pair 604...
# processing pair 605...
# processing pair 606...
# processing pair 607...
# processing pair 608...
# processing pair 609...
# processing pair 610...
# processing pair 611...
# processing pair 612...
# processing pair 613...
# processing pair 614...
# processing pair 615...
# processing pair 616...
# processing pair 617...
# processing pair 618...
# processing pair 619...
# processing pair 620...
# processing pair 621...
# processing pair 622...
# processing pair 623...
# processing pair 624...
# processing pair 625...
# processing pair 626...
# processing pair 627...
# processing pair 628...
# processing pair 629...
# processing pair 630...
# processing pair 631...
# processing pair 632...
# processing pair 633...
# processing pair 634...
# processing pair 635...
# processing pair 636...
# processing pair 637...
# processing pair 638...
# processing pair 639...
# processing pair 640...
# processing pair 641...
# processing pair 642...
# processing pair 643...
# processing pair 644...
# processing pair 645...
# processing pair 646...
# processing pair 647...
# processing pair 648...
# processing pair 649...
# processing pair 650...
# processing pair 651...
# processing pair 652...
# processing pair 653...
# processing pair 654...
# processing pair 655...
# processing pair 656...
# processing pair 657...
# processing pair 658...
# processing pair 659...
# processing pair 660...
# processing pair 661...
# processing pair 662...
# processing pair 663...
# processing pair 664...
# processing pair 665...
# processing pair 666...
# processing pair 667...
# processing pair 668...
# processing pair 669...
# processing pair 670...
# processing pair 671...
# processing pair 672...
# processing pair 673...
# processing pair 674...
# processing pair 675...
# processing pair 676...
# processing pair 677...
# processing pair 678...
# processing pair 679...
# processing pair 680...
# processing pair 681...
# processing pair 682...
# processing pair 683...
# processing pair 684...
# processing pair 685...
# processing pair 686...
# processing pair 687...
# processing pair 688...
# processing pair 689...
# processing pair 690...
# processing pair 691...
# processing pair 692...
# processing pair 693...
# processing pair 694...
# processing pair 695...
# processing pair 696...
# processing pair 697...
# processing pair 698...
# processing pair 699...
# processing pair 700...
# processing pair 701...
# processing pair 702...
# processing pair 703...
# processing pair 704...
# processing pair 705...
# processing pair 706...
# processing pair 707...
# processing pair 708...
# processing pair 709...
# processing pair 710...
# processing pair 711...
# processing pair 712...
# processing pair 713...
# processing pair 714...
# processing pair 715...
# processing pair 716...
# processing pair 717...
# processing pair 718...
# processing pair 719...
# processing pair 720...
# processing pair 721...
# processing pair 722...
# processing pair 723...
# processing pair 724...
# processing pair 725...
# processing pair 726...
# processing pair 727...
# processing pair 728...
# processing pair 729...
# processing pair 730...
# processing pair 731...
# processing pair 732...
# processing pair 733...
# processing pair 734...
# processing pair 735...
# processing pair 736...
# processing pair 737...
# processing pair 738...
# processing pair 739...
# processing pair 740...
# processing pair 741...
# processing pair 742...
# processing pair 743...
# processing pair 744...
# processing pair 745...
# processing pair 746...
# processing pair 747...
# processing pair 748...
# processing pair 749...
# processing pair 750...
# processing pair 751...
# processing pair 752...
# processing pair 753...
# processing pair 754...
# processing pair 755...
# processing pair 756...
# processing pair 757...
# processing pair 758...
# processing pair 759...
# processing pair 760...
# processing pair 761...
# processing pair 762...
# processing pair 763...
# processing pair 764...
# processing pair 765...
# processing pair 766...
# processing pair 767...
# processing pair 768...
# processing pair 769...
# processing pair 770...
# processing pair 771...
# processing pair 772...
# processing pair 773...
# processing pair 774...
# processing pair 775...
# processing pair 776...
# processing pair 777...
# processing pair 778...
# processing pair 779...
# processing pair 780...
# processing pair 781...
# processing pair 782...
# processing pair 783...
# processing pair 784...
# processing pair 785...
# processing pair 786...
# processing pair 787...
# processing pair 788...
# processing pair 789...
# processing pair 790...
# processing pair 791...
# processing pair 792...
# processing pair 793...
# processing pair 794...
# processing pair 795...
# processing pair 796...
# processing pair 797...
# processing pair 798...
# processing pair 799...
# processing pair 800...
# processing pair 801...
# processing pair 802...
# processing pair 803...
# processing pair 804...
# processing pair 805...
# processing pair 806...
# processing pair 807...
# processing pair 808...
# processing pair 809...
# processing pair 810...
# processing pair 811...
# processing pair 812...
# processing pair 813...
# processing pair 814...
# processing pair 815...
# processing pair 816...
# processing pair 817...
# processing pair 818...
# processing pair 819...
# processing pair 820...
# processing pair 821...
# processing pair 822...
# processing pair 823...
# processing pair 824...
# processing pair 825...
# processing pair 826...
# processing pair 827...
# processing pair 828...
# processing pair 829...
# processing pair 830...
# processing pair 831...
# processing pair 832...
# processing pair 833...
# processing pair 834...
# processing pair 835...
# processing pair 836...
# processing pair 837...
# processing pair 838...
# processing pair 839...
# processing pair 840...
# processing pair 841...
# processing pair 842...
# processing pair 843...
# processing pair 844...
# processing pair 845...
# processing pair 846...
# processing pair 847...
# processing pair 848...
# processing pair 849...
# processing pair 850...
# processing pair 851...
# processing pair 852...
# processing pair 853...
# processing pair 854...
# processing pair 855...
# processing pair 856...
# processing pair 857...
# processing pair 858...
# processing pair 859...
# processing pair 860...
# processing pair 861...
# processing pair 862...
# processing pair 863...
# processing pair 864...
# processing pair 865...
# processing pair 866...
# processing pair 867...
# processing pair 868...
# processing pair 869...
# processing pair 870...
# processing pair 871...
# processing pair 872...
# processing pair 873...
# processing pair 874...
# processing pair 875...
# processing pair 876...
# processing pair 877...
# processing pair 878...
# processing pair 879...
# processing pair 880...
# processing pair 881...
# processing pair 882...
# processing pair 883...
# processing pair 884...
# processing pair 885...
# processing pair 886...
# processing pair 887...
# processing pair 888...
# processing pair 889...
# processing pair 890...
# processing pair 891...
# processing pair 892...
# processing pair 893...
# processing pair 894...
# processing pair 895...
# processing pair 896...
# processing pair 897...
# processing pair 898...
# processing pair 899...
# processing pair 900...
# processing pair 901...
# processing pair 902...
# processing pair 903...
# processing pair 904...
# processing pair 905...
# processing pair 906...
# processing pair 907...
# processing pair 908...
# processing pair 909...
# processing pair 910...
# processing pair 911...
# processing pair 912...
# processing pair 913...
# processing pair 914...
# processing pair 915...
# processing pair 916...
# processing pair 917...
# processing pair 918...
# processing pair 919...
# processing pair 920...
# processing pair 921...
# processing pair 922...
# processing pair 923...
# processing pair 924...
# processing pair 925...
# processing pair 926...
# processing pair 927...
# processing pair 928...
# processing pair 929...
# processing pair 930...
# processing pair 931...
# processing pair 932...
# processing pair 933...
# processing pair 934...
# processing pair 935...
# processing pair 936...
# processing pair 937...
# processing pair 938...
# processing pair 939...
# processing pair 940...
# processing pair 941...
# processing pair 942...
# processing pair 943...
# processing pair 944...
# processing pair 945...
# processing pair 946...
# processing pair 947...
# processing pair 948...
# processing pair 949...
# processing pair 950...
# processing pair 951...
# processing pair 952...
# processing pair 953...
# processing pair 954...
# processing pair 955...
# processing pair 956...
# processing pair 957...
# processing pair 958...
# processing pair 959...
# processing pair 960...
# processing pair 961...
# processing pair 962...
# processing pair 963...
# processing pair 964...
# processing pair 965...
# processing pair 966...
# processing pair 967...
# processing pair 968...
# processing pair 969...
# processing pair 970...
# processing pair 971...
# processing pair 972...
# processing pair 973...
# processing pair 974...
# processing pair 975...
# processing pair 976...
# processing pair 977...
# processing pair 978...
# processing pair 979...
# processing pair 980...
# processing pair 981...
# processing pair 982...
# processing pair 983...
# processing pair 984...
# processing pair 985...
# processing pair 986...
# processing pair 987...
# processing pair 988...
# processing pair 989...
# processing pair 990...
# processing pair 991...
# processing pair 992...
# processing pair 993...
# processing pair 994...
# processing pair 995...
# processing pair 996...
# processing pair 997...
# processing pair 998...
# processing pair 999...
# processing pair 1000...
# processing pair 1001...
# processing pair 1002...
# processing pair 1003...
# processing pair 1004...
# processing pair 1005...
# processing pair 1006...
# processing pair 1007...
# processing pair 1008...
# processing pair 1009...
# processing pair 1010...
# processing pair 1011...
# processing pair 1012...
# processing pair 1013...
# processing pair 1014...
# processing pair 1015...
# processing pair 1016...
# processing pair 1017...
# processing pair 1018...
# processing pair 1019...
# processing pair 1020...
# processing pair 1021...
# processing pair 1022...
# processing pair 1023...
# processing pair 1024...
# processing pair 1025...
# processing pair 1026...
# processing pair 1027...
# processing pair 1028...
# processing pair 1029...
# processing pair 1030...
# processing pair 1031...
# processing pair 1032...
# processing pair 1033...
# processing pair 1034...
# processing pair 1035...
# processing pair 1036...
# processing pair 1037...
# processing pair 1038...
# processing pair 1039...
# processing pair 1040...
# processing pair 1041...
# processing pair 1042...
# processing pair 1043...
# processing pair 1044...
# processing pair 1045...
# processing pair 1046...
# processing pair 1047...
# processing pair 1048...
# processing pair 1049...
# processing pair 1050...
# processing pair 1051...
# processing pair 1052...
# processing pair 1053...
# processing pair 1054...
# processing pair 1055...
# processing pair 1056...
# processing pair 1057...
# processing pair 1058...
# processing pair 1059...
# processing pair 1060...
# processing pair 1061...
# processing pair 1062...
# processing pair 1063...
# processing pair 1064...
# processing pair 1065...
# processing pair 1066...
# processing pair 1067...
# processing pair 1068...
# processing pair 1069...
# processing pair 1070...
# processing pair 1071...
# processing pair 1072...
# processing pair 1073...
# processing pair 1074...
# processing pair 1075...
# processing pair 1076...
# processing pair 1077...
# processing pair 1078...
# processing pair 1079...
# processing pair 1080...
# processing pair 1081...
# processing pair 1082...
# processing pair 1083...
# processing pair 1084...
# processing pair 1085...
# processing pair 1086...
# processing pair 1087...
# processing pair 1088...
# processing pair 1089...
# processing pair 1090...
# processing pair 1091...
# processing pair 1092...
# processing pair 1093...
# processing pair 1094...
# processing pair 1095...
# processing pair 1096...
# processing pair 1097...
# processing pair 1098...
# processing pair 1099...
# processing pair 1100...
# processing pair 1101...
# processing pair 1102...
# processing pair 1103...
# processing pair 1104...
# processing pair 1105...
# processing pair 1106...
# processing pair 1107...
# processing pair 1108...
# processing pair 1109...
# processing pair 1110...
# processing pair 1111...
# processing pair 1112...
# processing pair 1113...
# processing pair 1114...
# processing pair 1115...
# processing pair 1116...
# processing pair 1117...
# processing pair 1118...
# processing pair 1119...
# processing pair 1120...
# processing pair 1121...
# processing pair 1122...
# processing pair 1123...
# processing pair 1124...
# processing pair 1125...
# processing pair 1126...
# processing pair 1127...
# processing pair 1128...
# processing pair 1129...
# processing pair 1130...
# processing pair 1131...
# processing pair 1132...
# processing pair 1133...
# processing pair 1134...
# processing pair 1135...
# processing pair 1136...
# processing pair 1137...
# processing pair 1138...
# processing pair 1139...
# processing pair 1140...
# processing pair 1141...
# processing pair 1142...
# processing pair 1143...
# processing pair 1144...
# processing pair 1145...
# processing pair 1146...
# processing pair 1147...
# processing pair 1148...
# processing pair 1149...
# processing pair 1150...
# processing pair 1151...
# processing pair 1152...
# processing pair 1153...
# processing pair 1154...
# processing pair 1155...
# processing pair 1156...
# processing pair 1157...
# processing pair 1158...
# processing pair 1159...
# processing pair 1160...
# processing pair 1161...
# processing pair 1162...
# processing pair 1163...
# processing pair 1164...
# processing pair 1165...
# processing pair 1166...
# processing pair 1167...
# processing pair 1168...
# processing pair 1169...
# processing pair 1170...
# processing pair 1171...
# processing pair 1172...
# processing pair 1173...
# processing pair 1174...
# processing pair 1175...
# processing pair 1176...
# processing pair 1177...
# processing pair 1178...
# processing pair 1179...
# processing pair 1180...
# processing pair 1181...
# processing pair 1182...
# processing pair 1183...
# processing pair 1184...
# processing pair 1185...
# processing pair 1186...
# processing pair 1187...
# processing pair 1188...
# processing pair 1189...
# processing pair 1190...
# processing pair 1191...
# processing pair 1192...
# processing pair 1193...
# processing pair 1194...
# processing pair 1195...
# processing pair 1196...
# processing pair 1197...
# processing pair 1198...
# processing pair 1199...
# processing pair 1200...
# processing pair 1201...
# processing pair 1202...
# processing pair 1203...
# processing pair 1204...
# processing pair 1205...
# processing pair 1206...
# processing pair 1207...
# processing pair 1208...
# processing pair 1209...
# processing pair 1210...
# processing pair 1211...
# processing pair 1212...
# processing pair 1213...
# processing pair 1214...
# processing pair 1215...
# processing pair 1216...
# processing pair 1217...
# processing pair 1218...
# processing pair 1219...
# processing pair 1220...
# processing pair 1221...
# processing pair 1222...
# processing pair 1223...
# processing pair 1224...
# processing pair 1225...
# processing pair 1226...
# processing pair 1227...
# processing pair 1228...
# processing pair 1229...
# processing pair 1230...
# processing pair 1231...
# processing pair 1232...
# processing pair 1233...
# processing pair 1234...
# processing pair 1235...
# processing pair 1236...
# processing pair 1237...
# processing pair 1238...
# processing pair 1239...
# processing pair 1240...
# processing pair 1241...
# processing pair 1242...
# processing pair 1243...
# processing pair 1244...
# processing pair 1245...
# processing pair 1246...
# processing pair 1247...
# processing pair 1248...
# processing pair 1249...
# processing pair 1250...
# processing pair 1251...
# processing pair 1252...
# processing pair 1253...
# processing pair 1254...
# processing pair 1255...
# processing pair 1256...
# processing pair 1257...
# processing pair 1258...
# processing pair 1259...
# processing pair 1260...
# processing pair 1261...
# processing pair 1262...
# processing pair 1263...
# processing pair 1264...
# processing pair 1265...
# processing pair 1266...
# processing pair 1267...
# processing pair 1268...
# processing pair 1269...
# processing pair 1270...
# processing pair 1271...
# processing pair 1272...
# processing pair 1273...
# processing pair 1274...
# processing pair 1275...
# processing pair 1276...
# processing pair 1277...
# processing pair 1278...
# processing pair 1279...
# processing pair 1280...
# processing pair 1281...
# processing pair 1282...
# processing pair 1283...
# processing pair 1284...
# processing pair 1285...
# processing pair 1286...
# processing pair 1287...
# processing pair 1288...
# processing pair 1289...
# processing pair 1290...
# processing pair 1291...
# processing pair 1292...
# processing pair 1293...
# processing pair 1294...
# processing pair 1295...
# processing pair 1296...
# processing pair 1297...
# processing pair 1298...
# processing pair 1299...
# processing pair 1300...
# processing pair 1301...
# processing pair 1302...
# processing pair 1303...
# processing pair 1304...
# processing pair 1305...
# processing pair 1306...
# processing pair 1307...
# processing pair 1308...
# processing pair 1309...
# processing pair 1310...
# processing pair 1311...
# processing pair 1312...
# processing pair 1313...
# processing pair 1314...
# processing pair 1315...
# processing pair 1316...
# processing pair 1317...
# processing pair 1318...
# processing pair 1319...
# processing pair 1320...
# processing pair 1321...
# processing pair 1322...
# processing pair 1323...
# processing pair 1324...
# processing pair 1325...
# processing pair 1326...
# processing pair 1327...
# processing pair 1328...
# processing pair 1329...
# processing pair 1330...
# processing pair 1331...
# processing pair 1332...
# processing pair 1333...
# processing pair 1334...
# processing pair 1335...
# processing pair 1336...
# processing pair 1337...
# processing pair 1338...
# processing pair 1339...
# processing pair 1340...
# processing pair 1341...
# processing pair 1342...
# processing pair 1343...
# processing pair 1344...
# processing pair 1345...
# processing pair 1346...
# processing pair 1347...
# processing pair 1348...
# processing pair 1349...
# processing pair 1350...
# processing pair 1351...
# processing pair 1352...
# processing pair 1353...
# processing pair 1354...
# processing pair 1355...
# processing pair 1356...
# processing pair 1357...
# processing pair 1358...
# processing pair 1359...
# processing pair 1360...
# processing pair 1361...
# processing pair 1362...
# processing pair 1363...
# processing pair 1364...
# processing pair 1365...
# processing pair 1366...
# processing pair 1367...
# processing pair 1368...
# processing pair 1369...
# processing pair 1370...
# processing pair 1371...
# processing pair 1372...
# processing pair 1373...
# processing pair 1374...
# processing pair 1375...
# processing pair 1376...
# processing pair 1377...
# processing pair 1378...
# processing pair 1379...
# processing pair 1380...
# processing pair 1381...
# processing pair 1382...
# processing pair 1383...
# processing pair 1384...
# processing pair 1385...
# processing pair 1386...
# processing pair 1387...
# processing pair 1388...
# processing pair 1389...
# processing pair 1390...
# processing pair 1391...
# processing pair 1392...
# processing pair 1393...
# processing pair 1394...
# processing pair 1395...
# processing pair 1396...
# processing pair 1397...
# processing pair 1398...
# processing pair 1399...
# processing pair 1400...
# processing pair 1401...
# processing pair 1402...
# processing pair 1403...
# processing pair 1404...
# processing pair 1405...
# processing pair 1406...
# processing pair 1407...
# processing pair 1408...
# processing pair 1409...
# processing pair 1410...
# processing pair 1411...
# processing pair 1412...
# processing pair 1413...
# processing pair 1414...
# processing pair 1415...
# processing pair 1416...
# processing pair 1417...
# processing pair 1418...
# processing pair 1419...
# processing pair 1420...
# processing pair 1421...
# processing pair 1422...
# processing pair 1423...
# processing pair 1424...
# processing pair 1425...
# processing pair 1426...
# processing pair 1427...
# processing pair 1428...
# processing pair 1429...
# processing pair 1430...
# processing pair 1431...
# processing pair 1432...
# processing pair 1433...
# processing pair 1434...
# processing pair 1435...
# processing pair 1436...
# processing pair 1437...
# processing pair 1438...
# processing pair 1439...
# processing pair 1440...
# processing pair 1441...
# processing pair 1442...
# processing pair 1443...
# processing pair 1444...
# processing pair 1445...
# processing pair 1446...
# processing pair 1447...
# processing pair 1448...
# processing pair 1449...
# processing pair 1450...
# processing pair 1451...
# processing pair 1452...
# processing pair 1453...
# processing pair 1454...
# processing pair 1455...
# processing pair 1456...
# processing pair 1457...
# processing pair 1458...
# processing pair 1459...
# processing pair 1460...
# processing pair 1461...
# processing pair 1462...
# processing pair 1463...
# processing pair 1464...
# processing pair 1465...
# processing pair 1466...
# processing pair 1467...
# processing pair 1468...
# processing pair 1469...
# processing pair 1470...
# processing pair 1471...
# processing pair 1472...
# processing pair 1473...
# processing pair 1474...
# processing pair 1475...
# processing pair 1476...
# processing pair 1477...
# processing pair 1478...
# processing pair 1479...
# processing pair 1480...
# processing pair 1481...
# processing pair 1482...
# processing pair 1483...
# processing pair 1484...
# processing pair 1485...
# processing pair 1486...
# processing pair 1487...
# processing pair 1488...
# processing pair 1489...
# processing pair 1490...
# processing pair 1491...
# processing pair 1492...
# processing pair 1493...
# processing pair 1494...
# processing pair 1495...
# processing pair 1496...
# processing pair 1497...
# processing pair 1498...
# processing pair 1499...
# processing pair 1500...
# processing pair 1501...
# processing pair 1502...
# processing pair 1503...
# processing pair 1504...
# processing pair 1505...
# processing pair 1506...
# processing pair 1507...
# processing pair 1508...
# processing pair 1509...
# processing pair 1510...
# processing pair 1511...
# processing pair 1512...
# processing pair 1513...
# processing pair 1514...
# processing pair 1515...
# processing pair 1516...
# processing pair 1517...
# processing pair 1518...
# processing pair 1519...
# processing pair 1520...
# processing pair 1521...
# processing pair 1522...
# processing pair 1523...
# processing pair 1524...
# processing pair 1525...
# processing pair 1526...
# processing pair 1527...
# processing pair 1528...
# processing pair 1529...
# processing pair 1530...
# processing pair 1531...
# processing pair 1532...
# processing pair 1533...
# processing pair 1534...
# processing pair 1535...
# processing pair 1536...
# processing pair 1537...
# processing pair 1538...
# processing pair 1539...
# processing pair 1540...
# processing pair 1541...
# processing pair 1542...
# processing pair 1543...
# processing pair 1544...
# processing pair 1545...
# processing pair 1546...
# processing pair 1547...
# processing pair 1548...
# processing pair 1549...
# processing pair 1550...
# processing pair 1551...
# processing pair 1552...
# processing pair 1553...
# processing pair 1554...
# processing pair 1555...
# processing pair 1556...
# processing pair 1557...
# processing pair 1558...
# processing pair 1559...
# processing pair 1560...
# processing pair 1561...
# processing pair 1562...
# processing pair 1563...
# processing pair 1564...
# processing pair 1565...
# processing pair 1566...
# processing pair 1567...
# processing pair 1568...
# processing pair 1569...
# processing pair 1570...
# processing pair 1571...
# processing pair 1572...
# processing pair 1573...
# processing pair 1574...
# processing pair 1575...
# processing pair 1576...
# processing pair 1577...
# processing pair 1578...
# processing pair 1579...
# processing pair 1580...
# processing pair 1581...
# processing pair 1582...
# processing pair 1583...
# processing pair 1584...
# processing pair 1585...
# processing pair 1586...
# processing pair 1587...
# processing pair 1588...
# processing pair 1589...
# processing pair 1590...
# processing pair 1591...
# processing pair 1592...
# processing pair 1593...
# processing pair 1594...
# processing pair 1595...
# processing pair 1596...
# processing pair 1597...
# processing pair 1598...
# processing pair 1599...
# processing pair 1600...
# processing pair 1601...
# processing pair 1602...
# processing pair 1603...
# processing pair 1604...
# processing pair 1605...
# processing pair 1606...
# processing pair 1607...
# processing pair 1608...
# processing pair 1609...
# processing pair 1610...
# processing pair 1611...
# processing pair 1612...
# processing pair 1613...
# processing pair 1614...
# processing pair 1615...
# processing pair 1616...
# processing pair 1617...
# processing pair 1618...
# processing pair 1619...
# processing pair 1620...
# processing pair 1621...
# processing pair 1622...
# processing pair 1623...
# processing pair 1624...
# processing pair 1625...
# processing pair 1626...
# processing pair 1627...
# processing pair 1628...
# processing pair 1629...
# processing pair 1630...
# processing pair 1631...
# processing pair 1632...
# processing pair 1633...
# processing pair 1634...
# processing pair 1635...
# processing pair 1636...
# processing pair 1637...
# processing pair 1638...
# processing pair 1639...
# processing pair 1640...
# processing pair 1641...
# processing pair 1642...
# processing pair 1643...
# processing pair 1644...
# processing pair 1645...
# processing pair 1646...
# processing pair 1647...
# processing pair 1648...
# processing pair 1649...
# processing pair 1650...
# processing pair 1651...
# processing pair 1652...
# processing pair 1653...
# processing pair 1654...
# processing pair 1655...
# processing pair 1656...
# processing pair 1657...
# processing pair 1658...
# processing pair 1659...
# processing pair 1660...
# processing pair 1661...
# processing pair 1662...
# processing pair 1663...
# processing pair 1664...
# processing pair 1665...
# processing pair 1666...
# processing pair 1667...
# processing pair 1668...
# processing pair 1669...
# processing pair 1670...
# processing pair 1671...
# processing pair 1672...
# processing pair 1673...
# processing pair 1674...
# processing pair 1675...
# processing pair 1676...
# processing pair 1677...
# processing pair 1678...
# processing pair 1679...
# processing pair 1680...
# processing pair 1681...
# processing pair 1682...
# processing pair 1683...
# processing pair 1684...
# processing pair 1685...
# processing pair 1686...
# processing pair 1687...
# processing pair 1688...
# processing pair 1689...
# processing pair 1690...
# processing pair 1691...
# processing pair 1692...
# processing pair 1693...
# processing pair 1694...
# processing pair 1695...
# processing pair 1696...
# processing pair 1697...
# processing pair 1698...
# processing pair 1699...
# processing pair 1700...
# processing pair 1701...
# processing pair 1702...
# processing pair 1703...
# processing pair 1704...
# processing pair 1705...
# processing pair 1706...
# processing pair 1707...
# processing pair 1708...
# processing pair 1709...
# processing pair 1710...
# processing pair 1711...
# processing pair 1712...
# processing pair 1713...
# processing pair 1714...
# processing pair 1715...
# processing pair 1716...
# processing pair 1717...
# processing pair 1718...
# processing pair 1719...
# processing pair 1720...
# processing pair 1721...
# processing pair 1722...
# processing pair 1723...
# processing pair 1724...
# processing pair 1725...
# processing pair 1726...
# processing pair 1727...
# processing pair 1728...
# processing pair 1729...
# processing pair 1730...
# processing pair 1731...
# processing pair 1732...
# processing pair 1733...
# processing pair 1734...
# processing pair 1735...
# processing pair 1736...
# processing pair 1737...
# processing pair 1738...
# processing pair 1739...
# processing pair 1740...
# processing pair 1741...
# processing pair 1742...
# processing pair 1743...
# processing pair 1744...
# processing pair 1745...
# processing pair 1746...
# processing pair 1747...
# processing pair 1748...
# processing pair 1749...
# processing pair 1750...
# processing pair 1751...
# processing pair 1752...
# processing pair 1753...
# processing pair 1754...
# processing pair 1755...
# processing pair 1756...
# processing pair 1757...
# processing pair 1758...
# processing pair 1759...
# processing pair 1760...
# processing pair 1761...
# processing pair 1762...
# processing pair 1763...
# processing pair 1764...
# processing pair 1765...
# processing pair 1766...
# processing pair 1767...
# processing pair 1768...
# processing pair 1769...
# processing pair 1770...
# processing pair 1771...
# processing pair 1772...
# processing pair 1773...
# processing pair 1774...
# processing pair 1775...
# processing pair 1776...
# processing pair 1777...
# processing pair 1778...
# processing pair 1779...
# processing pair 1780...
# processing pair 1781...
# processing pair 1782...
# processing pair 1783...
# processing pair 1784...
# processing pair 1785...
# processing pair 1786...
# processing pair 1787...
# processing pair 1788...
# processing pair 1789...
# processing pair 1790...
# processing pair 1791...
# processing pair 1792...
# processing pair 1793...
# processing pair 1794...
# processing pair 1795...
# processing pair 1796...
# processing pair 1797...
# processing pair 1798...
# processing pair 1799...
# processing pair 1800...
# processing pair 1801...
# processing pair 1802...
# processing pair 1803...
# processing pair 1804...
# processing pair 1805...
# processing pair 1806...
# processing pair 1807...
# processing pair 1808...
# processing pair 1809...
# processing pair 1810...
# processing pair 1811...
# processing pair 1812...
# processing pair 1813...
# processing pair 1814...
# processing pair 1815...
# processing pair 1816...
# processing pair 1817...
# processing pair 1818...
# processing pair 1819...
# processing pair 1820...
# processing pair 1821...
# processing pair 1822...
# processing pair 1823...
# processing pair 1824...
# processing pair 1825...
# processing pair 1826...
# processing pair 1827...
# processing pair 1828...
# processing pair 1829...
# processing pair 1830...
# processing pair 1831...
# processing pair 1832...
# processing pair 1833...
# processing pair 1834...
# processing pair 1835...
# processing pair 1836...
# processing pair 1837...
# processing pair 1838...
# processing pair 1839...
# processing pair 1840...
# processing pair 1841...
# processing pair 1842...
# processing pair 1843...
# processing pair 1844...
# processing pair 1845...
# processing pair 1846...
# processing pair 1847...
# processing pair 1848...
# processing pair 1849...
# processing pair 1850...
# processing pair 1851...
# processing pair 1852...
# processing pair 1853...
# processing pair 1854...
# processing pair 1855...
# processing pair 1856...
# processing pair 1857...
# processing pair 1858...
# processing pair 1859...
# processing pair 1860...
# processing pair 1861...
# processing pair 1862...
# processing pair 1863...
# processing pair 1864...
# processing pair 1865...
# processing pair 1866...
# processing pair 1867...
# processing pair 1868...
# processing pair 1869...
# processing pair 1870...
# processing pair 1871...
# processing pair 1872...
# processing pair 1873...
# processing pair 1874...
# processing pair 1875...
# processing pair 1876...
# processing pair 1877...
# processing pair 1878...
# processing pair 1879...
# processing pair 1880...
# processing pair 1881...
# processing pair 1882...
# processing pair 1883...
# processing pair 1884...
# processing pair 1885...
# processing pair 1886...
# processing pair 1887...
# processing pair 1888...
# processing pair 1889...
# processing pair 1890...
# processing pair 1891...
# processing pair 1892...
# processing pair 1893...
# processing pair 1894...
# processing pair 1895...
# processing pair 1896...
# processing pair 1897...
# processing pair 1898...
# processing pair 1899...
# processing pair 1900...
# processing pair 1901...
# processing pair 1902...
# processing pair 1903...
# processing pair 1904...
# processing pair 1905...
# processing pair 1906...
# processing pair 1907...
# processing pair 1908...
# processing pair 1909...
# processing pair 1910...
# processing pair 1911...
# processing pair 1912...
# processing pair 1913...
# processing pair 1914...
# processing pair 1915...
# processing pair 1916...
# processing pair 1917...
# processing pair 1918...
# processing pair 1919...
# processing pair 1920...
# processing pair 1921...
# processing pair 1922...
# processing pair 1923...
# processing pair 1924...
# processing pair 1925...
# processing pair 1926...
# processing pair 1927...
# processing pair 1928...
# processing pair 1929...
# processing pair 1930...
# processing pair 1931...
# processing pair 1932...
# processing pair 1933...
# processing pair 1934...
# processing pair 1935...
# processing pair 1936...
# processing pair 1937...
# processing pair 1938...
# processing pair 1939...
# processing pair 1940...
# processing pair 1941...
# processing pair 1942...
# processing pair 1943...
# processing pair 1944...
# processing pair 1945...
# processing pair 1946...
# processing pair 1947...
# processing pair 1948...
# processing pair 1949...
# processing pair 1950...
# processing pair 1951...
# processing pair 1952...
# processing pair 1953...
# processing pair 1954...
# processing pair 1955...
# processing pair 1956...
# processing pair 1957...
# processing pair 1958...
# processing pair 1959...
# processing pair 1960...
# processing pair 1961...
# processing pair 1962...
# processing pair 1963...
# processing pair 1964...
# processing pair 1965...
# processing pair 1966...
# processing pair 1967...
# processing pair 1968...
# processing pair 1969...
# processing pair 1970...
# processing pair 1971...
# processing pair 1972...
# processing pair 1973...
# processing pair 1974...
# processing pair 1975...
# processing pair 1976...
# processing pair 1977...
# processing pair 1978...
# processing pair 1979...
# processing pair 1980...
# processing pair 1981...
# processing pair 1982...
# processing pair 1983...
# processing pair 1984...
# processing pair 1985...
# processing pair 1986...
# processing pair 1987...
# processing pair 1988...
# processing pair 1989...
# processing pair 1990...
# processing pair 1991...
# processing pair 1992...
# processing pair 1993...
# processing pair 1994...
# processing pair 1995...
# processing pair 1996...
# processing pair 1997...
# processing pair 1998...
# processing pair 1999...
# processing pair 2000...
# processing pair 2001...
# processing pair 2002...
# processing pair 2003...
# processing pair 2004...
# processing pair 2005...
# processing pair 2006...
# processing pair 2007...
# processing pair 2008...
# processing pair 2009...
# processing pair 2010...
# processing pair 2011...
# processing pair 2012...
# processing pair 2013...
# processing pair 2014...
# processing pair 2015...
# processing pair 2016...
# processing pair 2017...
# processing pair 2018...
# processing pair 2019...
# processing pair 2020...
# processing pair 2021...
# processing pair 2022...
# processing pair 2023...
# processing pair 2024...
# processing pair 2025...
# processing pair 2026...
# processing pair 2027...
# processing pair 2028...
# processing pair 2029...
# processing pair 2030...
# processing pair 2031...
# processing pair 2032...
# processing pair 2033...
# processing pair 2034...
# processing pair 2035...
# processing pair 2036...
# processing pair 2037...
# processing pair 2038...
# processing pair 2039...
# processing pair 2040...
# processing pair 2041...
# processing pair 2042...
# ...
# processing pair 12329...
# processing pair 12330...
# processing pair 12331...
# processing pair 12332...
# processing pair 12333...
# processing pair 12334...
# processing pair 12335...
# processing pair 12336...
# processing pair 12337...
# processing pair 12338...
# processing pair 12339...
# processing pair 12340...
# processing pair 12341...
# processing pair 12342...
# processing pair 12343...
# processing pair 12344...
# processing pair 12345...
# processing pair 12346...
# processing pair 12347...
# processing pair 12348...
# processing pair 12349...
# processing pair 12350...
# processing pair 12351...
# processing pair 12352...
# processing pair 12353...
# processing pair 12354...
# processing pair 12355...
# processing pair 12356...
# processing pair 12357...
# processing pair 12358...
# processing pair 12359...
# processing pair 12360...
# processing pair 12361...
# processing pair 12362...
# processing pair 12363...
# processing pair 12364...
# processing pair 12365...
# processing pair 12366...
# processing pair 12367...
# processing pair 12368...
# processing pair 12369...
# processing pair 12370...
# processing pair 12371...
# processing pair 12372...
# processing pair 12373...
# processing pair 12374...
# processing pair 12375...
# processing pair 12376...
# processing pair 12377...
# processing pair 12378...
# processing pair 12379...
# processing pair 12380...
# processing pair 12381...
# processing pair 12382...
# processing pair 12383...
# processing pair 12384...
# processing pair 12385...
# processing pair 12386...
# processing pair 12387...
# processing pair 12388...
# processing pair 12389...
# processing pair 12390...
# processing pair 12391...
# processing pair 12392...
# processing pair 12393...
# processing pair 12394...
# processing pair 12395...
# processing pair 12396...
# processing pair 12397...
# processing pair 12398...
# processing pair 12399...
# processing pair 12400...
# processing pair 12401...
# processing pair 12402...
# processing pair 12403...
# processing pair 12404...
# processing pair 12405...
# processing pair 12406...
# processing pair 12407...
# processing pair 12408...
# processing pair 12409...
# processing pair 12410...
# processing pair 12411...
# processing pair 12412...
# processing pair 12413...
# processing pair 12414...
# processing pair 12415...
# processing pair 12416...
# processing pair 12417...
# processing pair 12418...
# processing pair 12419...
# processing pair 12420...
# processing pair 12421...
# processing pair 12422...
# processing pair 12423...
# processing pair 12424...
# processing pair 12425...
# processing pair 12426...
# processing pair 12427...
# processing pair 12428...
# processing pair 12429...
# processing pair 12430...
# processing pair 12431...
# processing pair 12432...
# processing pair 12433...
# processing pair 12434...
# processing pair 12435...
# processing pair 12436...
# processing pair 12437...
# processing pair 12438...
# processing pair 12439...
# processing pair 12440...
# processing pair 12441...
# processing pair 12442...
# processing pair 12443...
# processing pair 12444...
# processing pair 12445...
# processing pair 12446...
# processing pair 12447...
# processing pair 12448...
# processing pair 12449...
# processing pair 12450...
# processing pair 12451...
# processing pair 12452...
# processing pair 12453...
# processing pair 12454...
# processing pair 12455...
# processing pair 12456...
# processing pair 12457...
# processing pair 12458...
# processing pair 12459...
# processing pair 12460...
# processing pair 12461...
# processing pair 12462...
# processing pair 12463...
# processing pair 12464...
# processing pair 12465...
# processing pair 12466...
# processing pair 12467...
# processing pair 12468...
# processing pair 12469...
# processing pair 12470...
# processing pair 12471...
# processing pair 12472...
# processing pair 12473...
# processing pair 12474...
# processing pair 12475...
# processing pair 12476...
# processing pair 12477...
# processing pair 12478...
# processing pair 12479...
# processing pair 12480...
# processing pair 12481...
# processing pair 12482...
# processing pair 12483...
# processing pair 12484...
# processing pair 12485...
# processing pair 12486...
# processing pair 12487...
# processing pair 12488...
# processing pair 12489...
# processing pair 12490...
# processing pair 12491...
# processing pair 12492...
# processing pair 12493...
# processing pair 12494...
# processing pair 12495...
# processing pair 12496...
# processing pair 12497...
# processing pair 12498...
# processing pair 12499...
# processing pair 12500...
# processing pair 12501...
# processing pair 12502...
# processing pair 12503...
# processing pair 12504...
# processing pair 12505...
# processing pair 12506...
# processing pair 12507...
# processing pair 12508...
# processing pair 12509...
# processing pair 12510...
# processing pair 12511...
# processing pair 12512...
# processing pair 12513...
# processing pair 12514...
# processing pair 12515...
# processing pair 12516...
# processing pair 12517...
# processing pair 12518...
# processing pair 12519...
# processing pair 12520...
# processing pair 12521...
# processing pair 12522...
# processing pair 12523...
# processing pair 12524...
# processing pair 12525...
# processing pair 12526...
# processing pair 12527...
# processing pair 12528...
# processing pair 12529...
# processing pair 12530...
# processing pair 12531...
# processing pair 12532...
# processing pair 12533...
# processing pair 12534...
# processing pair 12535...
# processing pair 12536...
# processing pair 12537...
# processing pair 12538...
# processing pair 12539...
# processing pair 12540...
# processing pair 12541...
# processing pair 12542...
# processing pair 12543...
# processing pair 12544...
# processing pair 12545...
# processing pair 12546...
# processing pair 12547...
# processing pair 12548...
# processing pair 12549...
# processing pair 12550...
# processing pair 12551...
# processing pair 12552...
# processing pair 12553...
# processing pair 12554...
# processing pair 12555...
# processing pair 12556...
# processing pair 12557...
# processing pair 12558...
# processing pair 12559...
# processing pair 12560...
# processing pair 12561...
# processing pair 12562...
# processing pair 12563...
# processing pair 12564...
# processing pair 12565...
# processing pair 12566...
# processing pair 12567...
# processing pair 12568...
# processing pair 12569...
# processing pair 12570...
# processing pair 12571...
# processing pair 12572...
# processing pair 12573...
# processing pair 12574...
# processing pair 12575...
# processing pair 12576...
# processing pair 12577...
# processing pair 12578...
# processing pair 12579...
# processing pair 12580...
# processing pair 12581...
# processing pair 12582...
# processing pair 12583...
# processing pair 12584...
# processing pair 12585...
# processing pair 12586...
# processing pair 12587...
# processing pair 12588...
# processing pair 12589...
# processing pair 12590...
# processing pair 12591...
# processing pair 12592...
# processing pair 12593...
# processing pair 12594...
# processing pair 12595...
# processing pair 12596...
# processing pair 12597...
# processing pair 12598...
# processing pair 12599...
# processing pair 12600...
# processing pair 12601...
# processing pair 12602...
# processing pair 12603...
# processing pair 12604...
# processing pair 12605...
# processing pair 12606...
# processing pair 12607...
# processing pair 12608...
# processing pair 12609...
# processing pair 12610...
# processing pair 12611...
# processing pair 12612...
# processing pair 12613...
# processing pair 12614...
# processing pair 12615...
# processing pair 12616...
# processing pair 12617...
# processing pair 12618...
# processing pair 12619...
# processing pair 12620...
# processing pair 12621...
# processing pair 12622...
# processing pair 12623...
# processing pair 12624...
# processing pair 12625...
# processing pair 12626...
# processing pair 12627...
# processing pair 12628...
# processing pair 12629...
# processing pair 12630...
# processing pair 12631...
# processing pair 12632...
# processing pair 12633...
# processing pair 12634...
# processing pair 12635...
# processing pair 12636...
# processing pair 12637...
# processing pair 12638...
# processing pair 12639...
# processing pair 12640...
# processing pair 12641...
# processing pair 12642...
# processing pair 12643...
# processing pair 12644...
# processing pair 12645...
# processing pair 12646...
# processing pair 12647...
# processing pair 12648...
# processing pair 12649...
# processing pair 12650...
# processing pair 12651...
# processing pair 12652...
# processing pair 12653...
# processing pair 12654...
# processing pair 12655...
# processing pair 12656...
# processing pair 12657...
# processing pair 12658...
# processing pair 12659...
# processing pair 12660...
# processing pair 12661...
# processing pair 12662...
# processing pair 12663...
# processing pair 12664...
# processing pair 12665...
# processing pair 12666...
# processing pair 12667...
# processing pair 12668...
# processing pair 12669...
# processing pair 12670...
# processing pair 12671...
# processing pair 12672...
# processing pair 12673...
# processing pair 12674...
# processing pair 12675...
# processing pair 12676...
# processing pair 12677...
# processing pair 12678...
# processing pair 12679...
# processing pair 12680...
# processing pair 12681...
# processing pair 12682...
# processing pair 12683...
# processing pair 12684...
# processing pair 12685...
# processing pair 12686...
# processing pair 12687...
# processing pair 12688...
# processing pair 12689...
# processing pair 12690...
# processing pair 12691...
# processing pair 12692...
# processing pair 12693...
# processing pair 12694...
# processing pair 12695...
# processing pair 12696...
# processing pair 12697...
# processing pair 12698...
# processing pair 12699...
# processing pair 12700...
# processing pair 12701...
# processing pair 12702...
# processing pair 12703...
# processing pair 12704...
# processing pair 12705...
# processing pair 12706...
# processing pair 12707...
# processing pair 12708...
# processing pair 12709...
# processing pair 12710...
# processing pair 12711...
# processing pair 12712...
# processing pair 12713...
# processing pair 12714...
# processing pair 12715...
# processing pair 12716...
# processing pair 12717...
# processing pair 12718...
# processing pair 12719...
# processing pair 12720...
# processing pair 12721...
# processing pair 12722...
# processing pair 12723...
# processing pair 12724...
# processing pair 12725...
# processing pair 12726...
# processing pair 12727...
# processing pair 12728...
# processing pair 12729...
# processing pair 12730...
# processing pair 12731...
# processing pair 12732...
# processing pair 12733...
# processing pair 12734...
# processing pair 12735...
# processing pair 12736...
# processing pair 12737...
# processing pair 12738...
# processing pair 12739...
# processing pair 12740...
# processing pair 12741...
# processing pair 12742...
# processing pair 12743...
# processing pair 12744...
# processing pair 12745...
# processing pair 12746...
# processing pair 12747...
# processing pair 12748...
# processing pair 12749...
# processing pair 12750...
# processing pair 12751...
# processing pair 12752...
# processing pair 12753...
# processing pair 12754...
# processing pair 12755...
# processing pair 12756...
# processing pair 12757...
# processing pair 12758...
# processing pair 12759...
# processing pair 12760...
# processing pair 12761...
# processing pair 12762...
# processing pair 12763...
# processing pair 12764...
# processing pair 12765...
# processing pair 12766...
# processing pair 12767...
# processing pair 12768...
# processing pair 12769...
# processing pair 12770...
# processing pair 12771...
# processing pair 12772...
# processing pair 12773...
# processing pair 12774...
# processing pair 12775...
# processing pair 12776...
# processing pair 12777...
# processing pair 12778...
# processing pair 12779...
# processing pair 12780...
# processing pair 12781...
# processing pair 12782...
# processing pair 12783...
# processing pair 12784...
# processing pair 12785...
# processing pair 12786...
# processing pair 12787...
# processing pair 12788...
# processing pair 12789...
# processing pair 12790...
# processing pair 12791...
# processing pair 12792...
# processing pair 12793...
# processing pair 12794...
# processing pair 12795...
# processing pair 12796...
# processing pair 12797...
# processing pair 12798...
# processing pair 12799...
# processing pair 12800...
# processing pair 12801...
# processing pair 12802...
# processing pair 12803...
# processing pair 12804...
# processing pair 12805...
# processing pair 12806...
# processing pair 12807...
# processing pair 12808...
# processing pair 12809...
# processing pair 12810...
# processing pair 12811...
# processing pair 12812...
# processing pair 12813...
# processing pair 12814...
# processing pair 12815...
# processing pair 12816...
# processing pair 12817...
# processing pair 12818...
# processing pair 12819...
# processing pair 12820...
# processing pair 12821...
# processing pair 12822...
# processing pair 12823...
# processing pair 12824...
# processing pair 12825...
# processing pair 12826...
# processing pair 12827...
# processing pair 12828...
# processing pair 12829...
# processing pair 12830...
# processing pair 12831...
# processing pair 12832...
# processing pair 12833...
# processing pair 12834...
# processing pair 12835...
# processing pair 12836...
# processing pair 12837...
# processing pair 12838...
# processing pair 12839...
# processing pair 12840...
# processing pair 12841...
# processing pair 12842...
# processing pair 12843...
# processing pair 12844...
# processing pair 12845...
# processing pair 12846...
# processing pair 12847...
# processing pair 12848...
# processing pair 12849...
# processing pair 12850...
# processing pair 12851...
# processing pair 12852...
# processing pair 12853...
# processing pair 12854...
# processing pair 12855...
# processing pair 12856...
# processing pair 12857...
# processing pair 12858...
# processing pair 12859...
# processing pair 12860...
# processing pair 12861...
# processing pair 12862...
# processing pair 12863...
# processing pair 12864...
# processing pair 12865...
# processing pair 12866...
# processing pair 12867...
# processing pair 12868...
# processing pair 12869...
# processing pair 12870...
# processing pair 12871...
# processing pair 12872...
# processing pair 12873...
# processing pair 12874...
# processing pair 12875...
# processing pair 12876...
# processing pair 12877...
# processing pair 12878...
# processing pair 12879...
# processing pair 12880...
# processing pair 12881...
# processing pair 12882...
# processing pair 12883...
# processing pair 12884...
# processing pair 12885...
# processing pair 12886...
# processing pair 12887...
# processing pair 12888...
# processing pair 12889...
# processing pair 12890...
# processing pair 12891...
# processing pair 12892...
# processing pair 12893...
# processing pair 12894...
# processing pair 12895...
# processing pair 12896...
# processing pair 12897...
# processing pair 12898...
# processing pair 12899...
# processing pair 12900...
# processing pair 12901...
# processing pair 12902...
# processing pair 12903...
# processing pair 12904...
# processing pair 12905...
# processing pair 12906...
# processing pair 12907...
# processing pair 12908...
# processing pair 12909...
# processing pair 12910...
# processing pair 12911...
# processing pair 12912...
# processing pair 12913...
# processing pair 12914...
# processing pair 12915...
# processing pair 12916...
# processing pair 12917...
# processing pair 12918...
# processing pair 12919...
# processing pair 12920...
# processing pair 12921...
# processing pair 12922...
# processing pair 12923...
# processing pair 12924...
# processing pair 12925...
# processing pair 12926...
# processing pair 12927...
# processing pair 12928...
# processing pair 12929...
# processing pair 12930...
# processing pair 12931...
# processing pair 12932...
# processing pair 12933...
# processing pair 12934...
# processing pair 12935...
# processing pair 12936...
# processing pair 12937...
# processing pair 12938...
# processing pair 12939...
# processing pair 12940...
# processing pair 12941...
# processing pair 12942...
# processing pair 12943...
# processing pair 12944...
# processing pair 12945...
# processing pair 12946...
# processing pair 12947...
# processing pair 12948...
# processing pair 12949...
# processing pair 12950...
# processing pair 12951...
# processing pair 12952...
# processing pair 12953...
# processing pair 12954...
# processing pair 12955...
# processing pair 12956...
# processing pair 12957...
# processing pair 12958...
# processing pair 12959...
# processing pair 12960...
# processing pair 12961...
# processing pair 12962...
# processing pair 12963...
# processing pair 12964...
# processing pair 12965...
# processing pair 12966...
# processing pair 12967...
# 4329
# 4329
# 4329
